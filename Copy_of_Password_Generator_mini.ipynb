# %% [markdown]
# <a href="https://colab.research.google.com/github/Cflynt86-tech/Password-Generator-mini/blob/main/Copy_of_Password_Generator_mini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string

characters = string.ascii_letters + string.digits + string.punctuation

def generate_password(length):
    password = ''.join(random.choice(characters) for _ in range(length))
    return password

length = int(input("How long should your password be?"))
print(f"Your password: {generate_password(length)}")
